# %% [markdown]
# #Cбор данных
#
# Рассмотрим сайт  http://fontanka.ru. На данном сайте нас интересует архив <a href =  'http://www.fontanka.ru/fontanka/arc/2015/all.html'>новостей</a> за 2015 год. Получим ссылки на каждый день 2015 года и сохраним в отдельный файл.

# %%
# необходимые пакеты 
import lxml.html
import requests
import codecs
import os
import shutil
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %%
#получим страницу с архивом за январь
path = "http://www.fontanka.ru/fontanka/arc/2015/all.html"
response = requests.get(path)
if response.status_code == 200:
    html = response.content
    tree = lxml.html.document_fromstring(html)
    
    links = tree.xpath("""//div[@class='calendar-inner']/table[@class='blank_year']//tr/td[@class='blank_monthcell']
        /table/tbody/tr/td[@class='dom']/a/@href""")
    with open('fontanka-year2015-links', 'w') as ouf:
        for link in links:
            ouf.write("http://fontanka.ru%s\n"%(link))

# %% [markdown]
# Теперь имеются ссылки на архив новостей на каждый день 2015 года. Нужно перейти по каждой ссылке на соответствующую страницу. На этой странице скачать ссылки на новости. <br>
# Каждая новость имеют категорию. Будем учитывать это.

# %%
with codecs.open('news_category_links', 'w', encoding="utf8") as ouf:
    with open('fontanka-year2015-links', 'r') as inf:
        summ = 0
        for link in inf:
            print link.strip(),
            response = requests.get(link)
            if response.status_code == 200:
                html = response.content
                tree = lxml.html.document_fromstring(html)

                links = tree.xpath('''/html/body/div[@class="wrapper clearfix"]/div[@class="main-col 
                clearfix"]/div[@class="big_center ml30 fll"]/div[@class="calendar-widget"]
                /div[@class="calendar-inner transition open"]/div[@class="calendar-list"]/div
                [@class="calendar-item"]/div[@class="calendar-item-title"]/a''')
                print len(links),
                summ += len(links)
                print summ
                for l in links:
                    link = l.attrib['href']
                    if link[0] != "/":
                        continue
                    category = l.getnext().getchildren()[0].text_content()
                    
                    ouf.write("%s\t%s\n" % (category, link))
# Out:
# http://fontanka.ru/fontanka/2015/01/01/all.html 66 66
# http://fontanka.ru/fontanka/2015/01/02/all.html 49 115
# http://fontanka.ru/fontanka/2015/01/03/all.html 84 199
# http://fontanka.ru/fontanka/2015/01/04/all.html 60 259
# http://fontanka.ru/fontanka/2015/01/05/all.html 55 314
# http://fontanka.ru/fontanka/2015/01/06/all.html 49 363
# http://fontanka.ru/fontanka/2015/01/07/all.html 97 460
# http://fontanka.ru/fontanka/2015/01/08/all.html 90 550
# http://fontanka.ru/fontanka/2015/01/09/all.html 98 648
# http://fontanka.ru/fontanka/2015/01/10/all.html 89 737
# http://fontanka.ru/fontanka/2015/01/11/all.html 103 840
# http://fontanka.ru/fontanka/2015/01/12/all.html 178 1018
# http://fontanka.ru/fontanka/2015/01/13/all.html 185 1203
# http://fontanka.ru/fontanka/2015/01/14/all.html 180 1383
# http://fontanka.ru/fontanka/2015/01/15/all.html 206 1589
# http://fontanka.ru/fontanka/2015/01/16/all.html 215 1804
# http://fontanka.ru/fontanka/2015/01/17/all.html 98 1902
# http://fontanka.ru/fontanka/2015/01/18/all.html 78 1980
# http://fontanka.ru/fontanka/2015/01/19/all.html 218 2198
# http://fontanka.ru/fontanka/2015/01/20/all.html 248 2446
# http://fontanka.ru/fontanka/2015/12/23/all.html 201 58357
# http://fontanka.ru/fontanka/2015/12/24/all.html 198 58555
# http://fontanka.ru/fontanka/2015/12/25/all.html 190 58745
# http://fontanka.ru/fontanka/2015/12/26/all.html 72 58817
# http://fontanka.ru/fontanka/2015/12/27/all.html 54 58871
# http://fontanka.ru/fontanka/2015/12/28/all.html 199 59070
# http://fontanka.ru/fontanka/2015/12/29/all.html 193 59263
# http://fontanka.ru/fontanka/2015/12/30/all.html 172 59435
# http://fontanka.ru/fontanka/2015/12/31/all.html 80 59515

# %% [markdown]
# Осталось скачать сами новости.

# %%
main_path = u"http://www.fontanka.ru"
path_for_saving_news = u'./all_news/'
number_of_news_downloaded = 0

cnt = 0
threshold = 47121
with codecs.open('news_category_links', 'r', encoding='utf8') as inf:
    for line in inf:
        cnt += 1
        print cnt, 
        if cnt < threshold:
            continue
	
        category, link = line.split('\t')
        link = link.strip()
        try:
            response = requests.get(main_path + link)
        except:
            print "Something bad (no response) with %s"%link
            continue
        
        if category not in os.listdir(path_for_saving_news):
            os.mkdir(path_for_saving_news + category)
        
        path_for_news = path_for_saving_news[2:] + category + '/'
        
        if response.status_code == 200:
            
            try:
                number_of_news_downloaded += 1
                html = response.content
                tree = lxml.html.document_fromstring(html)
                txt = tree.xpath("""//div[@class='article']/div[@class='article_desc']
                /div[@class='article_fulltext']/p/text()""")
                filename = link.replace("/", "_")
                with codecs.open(path_for_news+filename, 'w', encoding="utf8") as ouf:
                    for t in txt:
                        ouf.write(t)
            except:
                print "Something bad with %s"%link
                    
        else:
            print "Something bad with %s"%link
        if (number_of_news_downloaded + threshold) % 10 == 1:
            print "%d \n"%(number_of_news_downloaded + threshold), 
            time.sleep(0.5)

# %% [markdown]
# Загрузилось около 47 тысяч статей. <br>
# Но среди полученных файлов есть пустые файлы (статьи), так как иногда ссылки вели на сторонние сайты. Избавимся от этого мусора. Также удалим папки в которых менее 100 статей.

# %%
path_with_news = './all_news/'
for d in os.listdir(path_with_news):
    path = path_with_news + d
    nFilesInDir = 0
    nDeletedFilesInDir = 0
    if os.path.isdir(path):
        print "Папка: '%s'"%d
        
        for f in os.listdir(path):
            filePath = path + '/' + f
            if os.path.getsize(filePath) < 100:
                nDeletedFilesInDir += 1
                os.remove(filePath)
            else:
                nFilesInDir += 1
    print "\tКоличество хороших файлов: %d, количество удаленных файлов: %d"%(nFilesInDir, nDeletedFilesInDir)
    if nFilesInDir < 100 :
        res = "Папка удалена"
        shutil.rmtree(path)
    else:
        res = "Папка оставлена"
    print "\tРезультат: %s"%res
# Out:
# Папка: 'Водитель Петербурга Live'
# 	Количество хороших файлов: 4, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Веселые старты'
# 	Количество хороших файлов: 0, количество удаленных файлов: 14
# 	Результат: Папка удалена
# Папка: 'Антон Мухин'
# 	Количество хороших файлов: 0, количество удаленных файлов: 6
# 	Результат: Папка удалена
# Папка: 'Власть'
# 	Количество хороших файлов: 5539, количество удаленных файлов: 49
# 	Результат: Папка оставлена
# Папка: 'Расскажи о солдате'
# 	Количество хороших файлов: 2, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Евгений Зеленев'
# 	Количество хороших файлов: 0, количество удаленных файлов: 3
# 	Результат: Папка удалена
# Папка: 'БеспринцЫпный клуб'
# 	Количество хороших файлов: 0, количество удаленных файлов: 10
# 	Результат: Папка удалена
# Папка: 'Очевидец'
# 	Количество хороших файлов: 2, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Александр Цыпкин'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Марианна Баконина'
# 	Количество хороших файлов: 0, количество удаленных файлов: 4
# 	Результат: Папка удалена
# Папка: 'Алексей Лепорк'
# 	Количество хороших файлов: 0, количество удаленных файлов: 6
# 	Результат: Папка удалена
# Папка: 'Опасная передача'
# 	Количество хороших файлов: 0, количество удаленных файлов: 15
# 	Результат: Папка удалена
# Папка: 'Александр Аликин'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Открытое письмо'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Евгений Вышенков'
# 	Количество хороших файлов: 0, количество удаленных файлов: 9
# 	Результат: Папка удалена
# Папка: 'В Теме'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Доска Почета'
# 	Количество хороших файлов: 0, количество удаленных файлов: 21
# 	Результат: Папка удалена
# Папка: 'Новый год'
# 	Количество хороших файлов: 13, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Технологии'
# 	Количество хороших файлов: 634, количество удаленных файлов: 5
# 	Результат: Папка оставлена
# Папка: 'Дмитрий Травин'
# 	Количество хороших файлов: 0, количество удаленных файлов: 14
# 	Результат: Папка удалена
# Папка: 'Территория права'
# 	Количество хороших файлов: 6, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Федор Погорелов'
# 	Количество хороших файлов: 1, количество удаленных файлов: 20
# 	Результат: Папка удалена
# Папка: 'Анатолий Несмиян'
# 	Количество хороших файлов: 0, количество удаленных файлов: 9
# 	Результат: Папка удалена
# Папка: 'Происшествия'
# 	Количество хороших файлов: 12681, количество удаленных файлов: 150
# 	Результат: Папка оставлена
# Папка: 'Охта центр'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Контур культуры'
# 	Количество хороших файлов: 0, количество удаленных файлов: 35
# 	Результат: Папка удалена
# Папка: 'Доступная среда'
# 	Количество хороших файлов: 7, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Андрей Константинов'
# 	Количество хороших файлов: 0, количество удаленных файлов: 4
# 	Результат: Папка удалена
# Папка: 'Фото'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Вкус жизни'
# 	Количество хороших файлов: 3, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Год N300'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Строительство'
# 	Количество хороших файлов: 590, количество удаленных файлов: 2
# 	Результат: Папка оставлена
# Папка: 'Александр Ткаченко'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Борис Подопригора'
# 	Количество хороших файлов: 0, количество удаленных файлов: 4
# 	Результат: Папка удалена
# Папка: 'Выборы'
# 	Количество хороших файлов: 49, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Вовремя с Венерой Галеевой'
# 	Количество хороших файлов: 0, количество удаленных файлов: 8
# 	Результат: Папка удалена
# Папка: 'Водитель Петербурга'
# 	Количество хороших файлов: 5, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Деньги'
# 	Количество хороших файлов: 376, количество удаленных файлов: 3
# 	Результат: Папка оставлена
# Папка: 'Автоклуб с Денисом Шубиным'
# 	Количество хороших файлов: 0, количество удаленных файлов: 15
# 	Результат: Папка удалена
# Папка: 'Работа'
# 	Количество хороших файлов: 186, количество удаленных файлов: 1
# 	Результат: Папка оставлена
# Папка: 'Театры'
# 	Количество хороших файлов: 1, количество удаленных файлов: 56
# 	Результат: Папка удалена
# Папка: 'Блогосфера'
# 	Количество хороших файлов: 0, количество удаленных файлов: 9
# 	Результат: Папка удалена
# Папка: '47новостей из Ленинградской Области'
# 	Количество хороших файлов: 19, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Светлана Шендерова'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Петербург.LIVE'
# 	Количество хороших файлов: 4, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Город 812'
# 	Количество хороших файлов: 0, количество удаленных файлов: 13
# 	Результат: Папка удалена
# Папка: 'Василий Кичеджи'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Итоги недели с Константиновым'
# 	Количество хороших файлов: 3, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Видео'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'День Победы'
# 	Количество хороших файлов: 24, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Лекции'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Недвижимость'
# 	Количество хороших файлов: 188, количество удаленных файлов: 111
# 	Результат: Папка оставлена
# Папка: 'Юрий Вдовин'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Туризм'
# 	Количество хороших файлов: 349, количество удаленных файлов: 32
# 	Результат: Папка оставлена
# Папка: 'Nota Bene'
# 	Количество хороших файлов: 0, количество удаленных файлов: 20
# 	Результат: Папка удалена
# Папка: 'Константин Ранкс'
# 	Количество хороших файлов: 0, количество удаленных файлов: 2
# 	Результат: Папка удалена
# Папка: 'Личная жизнь'
# 	Количество хороших файлов: 31, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Рецепты шеф-поваров'
# 	Количество хороших файлов: 3, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Дороги'
# 	Количество хороших файлов: 36, количество удаленных файлов: 2
# 	Результат: Папка удалена
# Папка: 'Выставки'
# 	Количество хороших файлов: 0, количество удаленных файлов: 19
# 	Результат: Папка удалена
# Папка: 'Андрей Анохин'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Бизнес-трибуна'
# 	Количество хороших файлов: 43, количество удаленных файлов: 2
# 	Результат: Папка удалена
# Папка: 'Эксперты'
# 	Количество хороших файлов: 2, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Вадим Тюльпанов'
# 	Количество хороших файлов: 0, количество удаленных файлов: 8
# 	Результат: Папка удалена
# Папка: 'Борис Вишневский'
# 	Количество хороших файлов: 0, количество удаленных файлов: 6
# 	Результат: Папка удалена
# Папка: 'СПб - 2014 в людях и цифрах'
# 	Количество хороших файлов: 8, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Тревожный город'
# 	Количество хороших файлов: 0, количество удаленных файлов: 11
# 	Результат: Папка удалена
# Папка: 'Евгений Хакназаров'
# 	Количество хороших файлов: 0, количество удаленных файлов: 2
# 	Результат: Папка удалена
# Папка: 'Водитель Петербурга.Live'
# 	Количество хороших файлов: 1, количество удаленных файлов: 9
# 	Результат: Папка удалена
# Папка: 'Итоги недели с Андреем Константиновым'
# 	Количество хороших файлов: 0, количество удаленных файлов: 13
# 	Результат: Папка удалена
# Папка: 'Валерий Федотов'
# 	Количество хороших файлов: 0, количество удаленных файлов: 6
# 	Результат: Папка удалена
# Папка: 'Кстати, сегодня'
# 	Количество хороших файлов: 0, количество удаленных файлов: 10
# 	Результат: Папка удалена
# Папка: 'Лучшая работа в мире'
# 	Количество хороших файлов: 0, количество удаленных файлов: 8
# 	Результат: Папка удалена
# Папка: 'Лев Лурье'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Здоровье и красота'
# 	Количество хороших файлов: 6, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'В теме с Аркадием Шароградским'
# 	Количество хороших файлов: 0, количество удаленных файлов: 46
# 	Результат: Папка удалена
# Папка: 'Фонтанка.Office'
# 	Количество хороших файлов: 16, количество удаленных файлов: 9
# 	Результат: Папка удалена
# Папка: 'Григорий Кунис'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Доктор Питер'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'ЖКХ'
# 	Количество хороших файлов: 494, количество удаленных файлов: 9
# 	Результат: Папка оставлена
# Папка: 'Андрей Заостровцев'
# 	Количество хороших файлов: 1, количество удаленных файлов: 16
# 	Результат: Папка удалена
# Папка: 'ЗЕНИТУ 90 ЛЕТ'
# 	Количество хороших файлов: 14, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Пока все в офисе'
# 	Количество хороших файлов: 0, количество удаленных файлов: 2
# 	Результат: Папка удалена
# Папка: 'Профессионал'
# 	Количество хороших файлов: 0, количество удаленных файлов: 48
# 	Результат: Папка удалена
# Папка: 'Общество'
# 	Количество хороших файлов: 10871, количество удаленных файлов: 157
# 	Результат: Папка оставлена
# Папка: 'Дмитрий Юрьев'
# 	Количество хороших файлов: 0, количество удаленных файлов: 2
# 	Результат: Папка удалена
# Папка: 'Бизнес в кризис'
# 	Количество хороших файлов: 8, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Экипаж'
# 	Количество хороших файлов: 5, количество удаленных файлов: 16
# 	Результат: Папка удалена
# Папка: 'Загородная недвижимость'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Музыка'
# 	Количество хороших файлов: 6, количество удаленных файлов: 79
# 	Результат: Папка удалена
# Папка: 'Точка опоры'
# 	Количество хороших файлов: 12, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Анонсы передач'
# 	Количество хороших файлов: 0, количество удаленных файлов: 27
# 	Результат: Папка удалена
# Папка: 'Среда джаза с Давидом Голощекиным'
# 	Количество хороших файлов: 0, количество удаленных файлов: 29
# 	Результат: Папка удалена
# Папка: 'Спроси сам'
# 	Количество хороших файлов: 37, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Елена Киселева'
# 	Количество хороших файлов: 0, количество удаленных файлов: 6
# 	Результат: Папка удалена
# Папка: 'Теракты'
# 	Количество хороших файлов: 6, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Активные трансляции'
# 	Количество хороших файлов: 0, количество удаленных файлов: 4
# 	Результат: Папка удалена
# Папка: 'Сетка вещания'
# 	Количество хороших файлов: 0, количество удаленных файлов: 5
# 	Результат: Папка удалена
# Папка: 'Книги'
# 	Количество хороших файлов: 4, количество удаленных файлов: 21
# 	Результат: Папка удалена
# Папка: 'Мужчина и женщина'
# 	Количество хороших файлов: 13, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Авто'
# 	Количество хороших файлов: 1265, количество удаленных файлов: 82
# 	Результат: Папка оставлена
# Папка: 'Материнский инстинкт'
# 	Количество хороших файлов: 10, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Реклама'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Большое интервью'
# 	Количество хороших файлов: 2, количество удаленных файлов: 12
# 	Результат: Папка удалена
# Папка: 'Городская недвижимость'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Кирпичики счастья'
# 	Количество хороших файлов: 1, количество удаленных файлов: 14
# 	Результат: Папка удалена
# Папка: 'Домашний очаг'
# 	Количество хороших файлов: 2, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Театральная гостиная'
# 	Количество хороших файлов: 3, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Финансы'
# 	Количество хороших файлов: 1933, количество удаленных файлов: 12
# 	Результат: Папка оставлена
# Папка: 'Надежда Кеворкова'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Спорт'
# 	Количество хороших файлов: 2617, количество удаленных файлов: 21
# 	Результат: Папка оставлена
# Папка: 'Город'
# 	Количество хороших файлов: 3205, количество удаленных файлов: 61
# 	Результат: Папка оставлена
# Папка: 'Культурный поводырь'
# 	Количество хороших файлов: 5, количество удаленных файлов: 12
# 	Результат: Папка удалена
# Папка: 'Бизнес'
# 	Количество хороших файлов: 3166, количество удаленных файлов: 64
# 	Результат: Папка оставлена
# Папка: 'Лахта центр'
# 	Количество хороших файлов: 13, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Кино'
# 	Количество хороших файлов: 4, количество удаленных файлов: 76
# 	Результат: Папка удалена
# Папка: 'Наталья Шатихина'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Виталий Милонов'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Жанна Зарецкая'
# 	Количество хороших файлов: 0, количество удаленных файлов: 4
# 	Результат: Папка удалена
# Папка: 'Хорошо!'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Наши лица'
# 	Количество хороших файлов: 0, количество удаленных файлов: 22
# 	Результат: Папка удалена
# Папка: 'Пресс-релизы'
# 	Количество хороших файлов: 8, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Доброе дело'
# 	Количество хороших файлов: 818, количество удаленных файлов: 2
# 	Результат: Папка оставлена
# Папка: 'Русфонд'
# 	Количество хороших файлов: 11, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Фонтанка.fi'
# 	Количество хороших файлов: 4, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Говорим и показываем'
# 	Количество хороших файлов: 6, количество удаленных файлов: 6
# 	Результат: Папка удалена
# Папка: 'Фонтанка. Перечитывая заново'
# 	Количество хороших файлов: 0, количество удаленных файлов: 2
# 	Результат: Папка удалена
# Папка: 'Новости компаний'
# 	Количество хороших файлов: 16, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Офис недели'
# 	Количество хороших файлов: 0, количество удаленных файлов: 12
# 	Результат: Папка удалена
# Папка: 'Афиша Plus'
# 	Количество хороших файлов: 17, количество удаленных файлов: 40
# 	Результат: Папка удалена
# Папка: 'Адвита'
# 	Количество хороших файлов: 4, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Николай Буров'
# 	Количество хороших файлов: 0, количество удаленных файлов: 1
# 	Результат: Папка удалена
# Папка: 'Ретро-советы'
# 	Количество хороших файлов: 3, количество удаленных файлов: 0
# 	Результат: Папка удалена
# Папка: 'Конкурсы'
# 	Количество хороших файлов: 1, количество удаленных файлов: 0
# 	Результат: Папка удалена

# %% [markdown]
# Посмотрим какие темы остались

# %%
ourTopics = {}
for d in os.listdir(path_with_news):
    ourTopics[d.decode('utf-8')] = len(os.listdir(path_with_news + d))

# %%
plt.figure(figsize=(20,10))
ind = np.arange(len(ourTopics.items()))
plt.bar(ind, ourTopics.values(), color='g', alpha = 0.7)

plt.title(u'Тематики')
plt.ylabel(u'Количество статей')
plt.xlabel(u'Названия статей')
plt.xticks(ind + 0.4, tuple(ourTopics.keys()), rotation = 45)
pass

# %% [markdown]
# # Предобработка данных
#
# Обработаем каждую из статей. Для каждой из статей возьмем текст и разобьем его по пробелу. Получим "слова", которые могут содержать знаки пунктуации, цифры. Выделим среди них "хорошие слова", которые будут характеризовать текст. Каждое "хорошее слово" приведем к нижнему регистру и найдем его лемму с помощью PyMorpy2. Также исключим стоп-слова (стоп слова взяти из пакетов nltk.stopwords и stop_words). Постараемся выделить аббревиатуры.
#
# <br> <i> можно попробовать pymystem3 для лемматизации </i>

# %% [markdown]
# Получим список стоп-слов. Зададим недопустимые знаки. Создадим морфологический анализатор.
# Реализуем вспомогательные функции для обработки текстовой строки, обработки слова.

# %%
from nltk.corpus import stopwords
import stop_words
import pymorphy2
import re
import codecs

stops = getStopWords()
forStrip = "".join(['.',',','!','?','"',"'",';',':','-',u'«',u'»'])
morph = pymorphy2.MorphAnalyzer()

def getStopWords():
    mystopwords = set(stopwords.words("russian"))
    mystopwords = set.union(mystopwords, stop_words.get_stop_words('russian'))
    return mystopwords

def relax_word(word, prev_word = None):
    """Обработка слова. Приведение к нормальному виду"""
    if len(word) < 2:
        return None
    
    # Удаление слов, в которых есть цифры (лучше считать отношение количества цифр к количеству букв)
    if re.search(r'\d', word):
        return None
    
    # Удаление знаков препинания и других символов с обеих концов строки
    word = word.strip(forStrip)
    
    # выделение аббревиатур
    if word.isupper() and len(word) > 1 and len(word) < 7:
        return word.lower()
    
    # Приведение к нижнему регистру
    word = word.lower()
    
    # Удаление стоп-слов
    if word in stops:
        return None
        
    # Лемматизация с помощью pymorpy2
    word = morph.parse(word)[0].normal_form
    
    return word

def prepocess(text):
    """ Функция получает строку текста и делает его преодработку """
    text = text.split()
    result = []
    for word in text:
        word = relax_word(word)
        if word:
            result.append(word)
    return " ".join(result)

# %% [markdown]
# Рассмотрим пример обработки строки: **В 10:32 на пульт дежурного "01" поступило сообщение о ДТП в Красногвардейском районе, сообщает сайт ГУ МЧС по Петербургу. Читатель "Фонтанки" между тем сообщил, что на углу проспектов Ударников и Индустриального лежит перевернутый автобус.**

# %%
test_string = u"""В 10:32 на пульт дежурного "01" поступило сообщение о ДТП в Красногвардейском районе, 
сообщает сайт ГУ МЧС по Петербургу. Читатель "Фонтанки" между 
тем сообщил, что на углу проспектов Ударников и Индустриального лежит перевернутый автобус."""

print prepocess(test_string)
# Out:
# пульт дежурный поступить сообщение дтп красногвардейский район сообщать сайт гу мчс петербург читатель фонтанка сообщить угол проспект ударник индустриальный лежать перевернуть автобус

# %% [markdown]
# ###Предобработка всей коллекции

# %%
news_path = "./all_news/"
preprocessedNews_path = "./preprocessedNews/"

news_category = os.listdir(news_path)
for nc in os.listdir(news_path):
    try:
        os.mkdir(preprocessedNews_path + nc)
    except:
        pass

# %%
for newsCat in os.listdir(news_path):
    print "Processed: %s\n"%newsCat
    for article in os.listdir(news_path + newsCat):
        with codecs.open(preprocessedNews_path + newsCat + '/' + article, 'w', 'utf8') as ouf:
            with codecs.open(news_path + newsCat + '/' + article, 'r', 'utf8') as inf:
                for line in inf:
                    if len(line) > 3:
                        ouf.write("%s "%prepocess(line))
# Out:
# Processed: Власть
#
# Processed: Технологии
#
# Processed: Происшествия
#
# Processed: Строительство
#
# Processed: Деньги
#
# Processed: Работа
#
# Processed: Недвижимость
#
# Processed: Туризм
#
# Processed: ЖКХ
#
# Processed: Общество
#
# Processed: Авто
#
# Processed: Финансы
#
# Processed: Спорт
#
# Processed: Город
#
# Processed: Бизнес
#
# Processed: Доброе дело

# %% [markdown]
# ### Подготовка данных для LDA

# %% [markdown]
# Выберем нужные нам темы и необходимое число статей для каждой темы. Словарь dataOption в качестве ключей хранит название темы, а в качестве значений число статей для соответствующей темы.

# %%
dataOption = {u'Власть' : 150, u'Происшествия':150, u'Бизнес':150, u'Спорт':150 }

# %%
from collections import defaultdict

wordToId = {}
idToDoc = {}

# docid : (nWords, [wordId])
docs = defaultdict(lambda : [])


last_wordid = -1
last_docid = -1

path = "./preprocessedNews/"

for topicName,nArticle in dataOption.items():
    list_articles = os.listdir(path + topicName)
    np.random.shuffle(list_articles)
    for article in list_articles[:nArticle]: 
        # Создадим id для статьи
        last_docid += 1
        idToDoc[last_docid] = topicName + '/' + article
        
        # Обработка статьи
        with codecs.open(path + topicName + '/' + article, 'r', 'utf8') as inf:
            for line in inf:
                for w in line.split():
                    if w not in wordToId.keys():
                        last_wordid += 1
                        wordToId[w] = last_wordid
                    docs[last_docid].append(str(wordToId[w]))
    print "%s done"%topicName
# Out:
# Власть done
# Происшествия done
# Спорт done
# Бизнес done

# %%
import json
name_of_corpus = "Corpus1"
try:
    os.mkdir(name_of_corpus) 
    corpus_path = "./%s/"%name_of_corpus

    json.dump(dataOption, codecs.open(corpus_path + "topicinfo.json", 'w', 'utf8'))
    #json.dump(wordToId, codecs.open(corpus_path + "wordid.json", 'w', 'utf8'))
    json.dump(idToDoc, codecs.open(corpus_path + "docid.json", 'w', 'utf8'))
    #json.dump(invertedIndex, codecs.open(corpus_path + "invertedIndex.json", 'w', 'utf8'))  
    with open(corpus_path + 'docs.lda', 'w') as ouf:
        for docid, wids in docs.items():
            ouf.write('%d\t%s\n'%(docid, " ".join(wids)))
    
        
    with codecs.open(corpus_path + 'vocab.lda', 'w', 'utf8') as ouf:
        for k,v in wordToId.items():
            ouf.write("%d\t%s\n"%(v, k))
            
    #with codecs.open(corpus_path + 'size.info', 'w', 'utf8') as ouf:
        #ouf.write('Words: %d\n'% len(wordToId.keys()))
        #ouf.write('Docs: %d\n'% len(idToDoc.keys()))
    
except:
    print "Что-то пошло не так"

# %% [markdown]
# <i> не все слова хорошие: примеры:</i> <br>
# нет…,данчарова),[длить, информацией»,—

# %%
print "Количество слов в словаре: %d" % len(wordToId.keys())
print "Количество документов: %d" % len(idToDoc.keys())
# Out:
# Количество слов в словаре: 12535
# Количество документов: 600

# %% [markdown]
# # LDA
# ## Реализация класса LDA

# %% [markdown]
#  <img src=smoothed_lda.png>

# %%
class LDA(object):
    def __init__(self, corpus_path, K, alpha = 0.1, beta = 0.1):
        self.K = K
        self.alpha = alpha
        self.beta = beta
        
        self.Voc = {}
        self.V = 0
        with codecs.open(corpus_path + 'vocab.lda', 'r', 'utf8') as inf:
            for line in inf:
                wid, word = line.split()
                self.Voc[int(wid)] = word
                self.V += 1
        
        self.docs = []
        self.M = 0
        with codecs.open(corpus_path + 'docs.lda', 'r', 'utf8') as inf:
            for line in inf:
                ##### needfix
                docid, wids = line.split('\t')
                if len(self.docs) != int(docid):
                    print "Ошибка с индексом документа"
                    return
                self.docs.append([int(wid) for wid in wids.split()])
                self.M += 1
        
        self.z_mn = []                                 # тема n-го слова в документе m
        self.n_mz = np.zeros((self.M, self.K)) + alpha # число слов в документе m с темой z
        self.n_zt = np.zeros((self.K, self.V)) + beta  # сколько раз слово t встречается в теме z
        self.n_z  = np.zeros((self.K)) + self.V*beta   # число слов в каждой теме
        
        # смотрим все документы
        for m, doc in enumerate(self.docs):
            # для каждого слова выбираем тему
            z_n = []                           # z_n[i] хранит тему для i-го слова
            
            # смотрим все слова в этом документе, wordid - ид слова, nw - сколько раз слово встречается в документе
            for t in doc:                
                # выбираем тему
                #z = np.random.randint(0, self.K)
                p_z = self.n_zt[:,t] * self.n_mz[m] / self.n_z
                z = np.random.multinomial(1, p_z / p_z.sum()).argmax()

                z_n.append(z)

                # обновляем матрицы
                self.n_mz[m, z]      += 1.0
                self.n_zt[z, t]      += 1.0
                self.n_z[z]          += 1.0
            self.z_mn.append(np.array(z_n))
            
    def iteration(self):
        """Одна итерация"""
        # смотрим все документы
        for m,doc in enumerate(self.docs):
            for n, t in enumerate(doc):
                # выбираем тему
                z = self.z_mn[m][n]
                #print self.n_mz[docid, z], self.n_zt[z, wordid], self.n_z[z]
                self.n_mz[m,z]   -= 1.0
                self.n_zt[z, t] -= 1.0
                self.n_z[z]          -= 1.0
                #print self.n_mz[docid, z], self.n_zt[z, wordid], self.n_z[z]

                #выбриаем новую тему
                p_z = (self.n_zt[:,m]) * (self.n_mz[m]) / (self.n_z)

                #print p_z
                #print p_z.sum()
                new_z = np.random.multinomial(1, p_z / p_z.sum()).argmax()

                self.z_mn[m][n] = new_z
                self.n_mz[m, new_z]      += 1.0
                self.n_zt[new_z, t]      += 1.0
                self.n_z[new_z]          += 1.0

    def get_phi(self):
        return self.n_zt / self.n_z[:, np.newaxis]
    
    def perplexity(self):
        phi = self.get_phi()
        N = 0
        logPerplexity = 0
        
        for m,doc in enumerate(self.docs):
            theta = self.n_mz[m] /(len(doc) + self.K * self.alpha)
            for w in doc:
                logPerplexity -= np.log(np.inner(phi[:,w], theta))
            N += len(doc)
        return np.exp(logPerplexity / N)
    
    
    def learn(self, n_iter):
        last_perplexity = self.perplexity()
        print "Начальное значение perplexity: %f" % last_perplexity
        for i in range(n_iter):
            self.iteration()
            perplexity = self.perplexity()
            print "Итерация %d: perplexity=%f"%(i+1,perplexity)
            if last_perplexity < perplexity:
                print "model is learned"
                return
        
    def get_wt_distribution(self):
        phi = self.get_phi()
        for i in range(self.K):
            print "topic %d"%i
            for w in np.argsort(-phi[k])[:10]:
                print "+ %f*%s"%(phi[k,w], self.Voc[w])

# %%
mylda = LDA('./Corpus1/', K=4, alpha=0.1, beta=0.1)

# %%
mylda.learn(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-ac0bb3d85a30> in <module>()
# ----> 1 mylda.learn(10)
#
# <ipython-input-69-1a79fb39b6c5> in learn(self, n_iter)
#      92
#      93     def learn(self, n_iter):
# ---> 94         last_perplexity = self.perplexity()
#      95         print "Начальное значение perplexity: %f" % last_perplexity
#      96         for i in range(n_iter):
#
# <ipython-input-69-1a79fb39b6c5> in perplexity(self)
#      79
#      80     def perplexity(self):
# ---> 81         phi = self.get_phi()
#      82         N = 0
#      83         logPerplexity = 0
#
# <ipython-input-69-1a79fb39b6c5> in get_phi(self)
#      76
#      77     def get_phi(self):
# ---> 78         return self.n_zt / self.n_z #[:, np.newaxis]
#      79
#      80     def perplexity(self):
#
# ValueError: operands could not be broadcast together with shapes (4,12414) (4,)
